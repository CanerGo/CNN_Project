# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import os

# %%
train = ImageDataGenerator(rescale = 1/255)
vali = ImageDataGenerator(rescale = 1/255)

# %%
train_dataset = train.flow_from_directory("my_dataset/train/",
                                         target_size = (100,100),
                                         batch_size = 15,
                                         shuffle = True,
                                         seed = 42,
                                         class_mode = "binary")
vali_dataset = vali.flow_from_directory("my_dataset/vali/",
                                         target_size = (100,100),
                                         batch_size = 15,
                                         shuffle = True,
                                         seed = 42,
                                         class_mode = "binary")
# Out:
# Found 1400 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %% [markdown]
# Meines CNN Modell

# %%
model = tf.keras.models.Sequential([
                                ### Convolutional-Layer 1
                                    tf.keras.layers.Conv2D(32,(3,3), activation = 'relu', input_shape = (100, 100, 3)),
                                    tf.keras.layers.Dropout(rate = 0.2),                               
                                    tf.keras.layers.MaxPool2D(2,2),
                                ### Convolutional-Layer 2
                                    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
                                    tf.keras.layers.Dropout(rate = 0.2),
                                    tf.keras.layers.MaxPool2D(2,2),
                                ### Dense-Hidden-Layer 1                                    
                                    tf.keras.layers.Dense(500, activation = 'relu', 
                                                          kernel_initializer = "he_normal", 
                                                          kernel_regularizer = tf.keras.regularizers.l2(l2 = 0.01)),
                                ### Flatten-Layer 
                                    tf.keras.layers.Flatten(),
                                ### Output-Layer
                                    tf.keras.layers.Dense(1, activation = 'sigmoid')
                                    ])

# %%
# Alle Schichten des Modells
model.summary()
Model:"sequential"
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 98, 98, 32)        896
#
#  dropout_12 (Dropout)        (None, 98, 98, 32)        0
#
#  max_pooling2d_12 (MaxPoolin  (None, 49, 49, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 47, 47, 64)        18496
#
#  dropout_13 (Dropout)        (None, 47, 47, 64)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  dense_12 (Dense)            (None, 23, 23, 500)       32500
#
#  flatten_6 (Flatten)         (None, 264500)            0
#
#  dense_13 (Dense)            (None, 1)                 264501
#
# =================================================================
# Total params: 316,393
# Trainable params: 316,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = RMSprop(learning_rate = 0.001, rho = 0.9)
#model.compile(loss = "binary_crossentropy",
#             optimizer = opt,
#             metrics = ["accuracy"])

# %%
opt = tf.keras.optimizers.Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999)
model.compile(loss = "binary_crossentropy",
             optimizer = opt,
             metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 4)

# %%
history = model.fit(train_dataset,
                     steps_per_epoch = 15,
                     epochs = 70,
                     validation_data = vali_dataset,
                     callbacks = [early_stopping])
# Out:
# Epoch 1/70
# 15/15 [==============================] - 4s 261ms/step - loss: 12.9602 - accuracy: 0.5302 - val_loss: 9.8566 - val_accuracy: 0.5000
# Epoch 2/70
# 15/15 [==============================] - 4s 265ms/step - loss: 9.4289 - accuracy: 0.4356 - val_loss: 8.7820 - val_accuracy: 0.6300
# Epoch 3/70
# 15/15 [==============================] - 4s 249ms/step - loss: 8.3889 - accuracy: 0.5422 - val_loss: 7.9377 - val_accuracy: 0.5000
# Epoch 4/70
# 15/15 [==============================] - 4s 274ms/step - loss: 7.5730 - accuracy: 0.4889 - val_loss: 7.1646 - val_accuracy: 0.5050
# Epoch 5/70
# 15/15 [==============================] - 4s 257ms/step - loss: 6.8326 - accuracy: 0.5511 - val_loss: 6.4724 - val_accuracy: 0.5000
# Epoch 6/70
# 15/15 [==============================] - 4s 276ms/step - loss: 6.1786 - accuracy: 0.5111 - val_loss: 5.8469 - val_accuracy: 0.4900
# Epoch 7/70
# 15/15 [==============================] - 4s 244ms/step - loss: 5.5817 - accuracy: 0.4933 - val_loss: 5.2840 - val_accuracy: 0.5000
# Epoch 8/70
# 15/15 [==============================] - 4s 241ms/step - loss: 5.0455 - accuracy: 0.5289 - val_loss: 4.7815 - val_accuracy: 0.6050
# Epoch 9/70
# 15/15 [==============================] - 4s 246ms/step - loss: 4.5711 - accuracy: 0.4844 - val_loss: 4.3343 - val_accuracy: 0.5050
# Epoch 10/70
# 15/15 [==============================] - 4s 243ms/step - loss: 4.1395 - accuracy: 0.5200 - val_loss: 3.9307 - val_accuracy: 0.5000
# Epoch 11/70
# 15/15 [==============================] - 4s 239ms/step - loss: 3.7624 - accuracy: 0.5628 - val_loss: 3.5738 - val_accuracy: 0.5000
# Epoch 12/70
# 15/15 [==============================] - 4s 241ms/step - loss: 3.4121 - accuracy: 0.5600 - val_loss: 3.2540 - val_accuracy: 0.5025
# Epoch 13/70
# 15/15 [==============================] - 4s 243ms/step - loss: 3.1155 - accuracy: 0.5467 - val_loss: 2.9670 - val_accuracy: 0.5000
# Epoch 14/70
# 15/15 [==============================] - 4s 244ms/step - loss: 2.8413 - accuracy: 0.5511 - val_loss: 2.7205 - val_accuracy: 0.4975
# Epoch 15/70
# 15/15 [==============================] - 4s 267ms/step - loss: 2.6055 - accuracy: 0.5244 - val_loss: 2.4870 - val_accuracy: 0.5475
# Epoch 16/70
# 15/15 [==============================] - 4s 250ms/step - loss: 2.3692 - accuracy: 0.6044 - val_loss: 2.4209 - val_accuracy: 0.5000
# Epoch 17/70
# 15/15 [==============================] - 4s 244ms/step - loss: 2.1834 - accuracy: 0.5511 - val_loss: 2.1016 - val_accuracy: 0.5050
# Epoch 18/70
# 15/15 [==============================] - 4s 240ms/step - loss: 2.0149 - accuracy: 0.5442 - val_loss: 1.9358 - val_accuracy: 0.5675
# Epoch 19/70
# 15/15 [==============================] - 4s 241ms/step - loss: 1.8735 - accuracy: 0.5953 - val_loss: 1.8010 - val_accuracy: 0.6050
# 15/15 [==============================] - 4s 246ms/step - loss: 0.6814 - accuracy: 0.7378 - val_loss: 0.8046 - val_accuracy: 0.5825
# Epoch 39/70
# 15/15 [==============================] - 4s 243ms/step - loss: 0.7242 - accuracy: 0.6533 - val_loss: 0.7866 - val_accuracy: 0.5825
# Epoch 40/70
# 15/15 [==============================] - 3s 240ms/step - loss: 0.6340 - accuracy: 0.7581 - val_loss: 0.9419 - val_accuracy: 0.5375
# Epoch 41/70
# 15/15 [==============================] - 4s 237ms/step - loss: 0.6825 - accuracy: 0.6791 - val_loss: 0.7745 - val_accuracy: 0.6100
# Epoch 42/70
# 15/15 [==============================] - 4s 238ms/step - loss: 0.6872 - accuracy: 0.6930 - val_loss: 0.7587 - val_accuracy: 0.6250
# Epoch 43/70
# 15/15 [==============================] - 4s 247ms/step - loss: 0.6262 - accuracy: 0.7244 - val_loss: 0.7736 - val_accuracy: 0.6100
# Epoch 44/70
# 15/15 [==============================] - 4s 242ms/step - loss: 0.6107 - accuracy: 0.7422 - val_loss: 0.8145 - val_accuracy: 0.5700
# Epoch 45/70
# 15/15 [==============================] - 4s 240ms/step - loss: 0.6117 - accuracy: 0.7333 - val_loss: 0.7488 - val_accuracy: 0.6125
# Epoch 46/70
# 15/15 [==============================] - 4s 253ms/step - loss: 0.5943 - accuracy: 0.7733 - val_loss: 0.7735 - val_accuracy: 0.5900
# Epoch 47/70
# 15/15 [==============================] - 4s 242ms/step - loss: 0.5456 - accuracy: 0.7822 - val_loss: 0.7906 - val_accuracy: 0.5725
# Epoch 48/70
# 15/15 [==============================] - 4s 239ms/step - loss: 0.5602 - accuracy: 0.7644 - val_loss: 0.8174 - val_accuracy: 0.5625
# Epoch 49/70
# 15/15 [==============================] - 4s 247ms/step - loss: 0.5131 - accuracy: 0.8044 - val_loss: 0.8143 - val_accuracy: 0.5500
# Epoch 49: early stopping

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 13)
plt.show()

# %%
dir_path = "my_dataset/test"

for i in os.listdir(dir_path):
    img = image.load_img(dir_path + '//' + i, target_size = (100, 100))
    plt.imshow(img)
    plt.show()

    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis = 0)
    images = np.vstack([img_array])
    predict = model.predict(images)
    if predict == 0:
        print("It is a cat")
    else:
        print("It is a dog")
# Out:
# 1/1 [==============================] - 0s 63ms/step
# It is a dog
# 1/1 [==============================] - 0s 16ms/step
# It is a dog
# 1/1 [==============================] - 0s 22ms/step
# It is a dog
# 1/1 [==============================] - 0s 16ms/step
# It is a dog
# 1/1 [==============================] - 0s 16ms/step
# It is a dog
# 1/1 [==============================] - 0s 17ms/step
# It is a dog
# 1/1 [==============================] - 0s 22ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5636/632954679.py in <module>
#       9     img_array = np.expand_dims(img_array, axis = 0)
#      10     images = np.vstack([img_array])
# ---> 11     predict = model.predict(images)
#      12     if predict == 0:
#      13         print("It is a cat")
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:
